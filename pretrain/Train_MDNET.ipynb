# %%
from train_mdnet_tensorboard import *

# %%
print(opts['model_path'])
opts['model_path'] = '../models/pymdnet-vot-attmask2-conv1&se3&loss3-1024.pth'
print(opts['model_path'])

opts['init_model_path'] = '../models/pymdnet-vot-attmask2-conv1&loss3-1023.pth'
# Out:
# ../models/pymdnet-vot-seblock-r16-0921.pth
# ../models/pymdnet-vot-attmask2-conv1&se3&loss3-1024.pth

# %%
train_mdnet()
# Out:
# ../models/pymdnet-vot-attmask2-conv1&loss3-1023.pth
# 500
# conv3_se_weight have already in param, so plus _2
# conv3_se_bias have already in param, so plus _2
# ==== Start Cycle 0 ====
# Cycle: 0,K: 9(169),Loss:(253.898),Prec:(0.156),Time:0.481,L_cls:232.644,L_ins:21.254
# Cycle: 0,K:19(345),Loss:(175.240),Prec:(0.000),Time:0.649,L_cls:160.029,L_ins:15.212
# Cycle: 0,K:29(294),Loss:(121.568),Prec:(0.375),Time:0.391,L_cls:107.236,L_ins:14.332
# Cycle: 0,K:39(386),Loss:(123.833),Prec:(0.500),Time:0.615,L_cls:108.627,L_ins:15.206
# Cycle: 0,K:49(377),Loss:(193.663),Prec:(0.656),Time:0.762,L_cls:182.857,L_ins:10.806
# Cycle: 0,K:59(32),Loss:(182.637),Prec:(0.188),Time:0.412,L_cls:167.173,L_ins:15.463
# Cycle: 0,K:69(36),Loss:(112.472),Prec:(0.438),Time:0.568,L_cls:95.277,L_ins:17.195
# Cycle: 0,K:79(276),Loss:(179.375),Prec:(0.594),Time:0.590,L_cls:159.611,L_ins:19.764
# Cycle: 0,K:89(347),Loss:(248.113),Prec:(0.094),Time:0.417,L_cls:230.298,L_ins:17.816
# ...

# %%
# a = MDNet(K=1)
# Out:
# conv3_se_weight have already in param, so plus _2
# conv3_se_bias have already in param, so plus _2

# %%
# for name, parms in a.named_parameters():
#     print(name,':',parms.size())
# Out:
# ('layers.conv1.0.weight', ':', torch.Size([96, 3, 7, 7]))
# ('layers.conv1.0.bias', ':', torch.Size([96]))
# ('layers.conv2.0.weight', ':', torch.Size([256, 96, 5, 5]))
# ('layers.conv2.0.bias', ':', torch.Size([256]))
# ('layers.conv3.0.weight', ':', torch.Size([512, 256, 3, 3]))
# ('layers.conv3.0.bias', ':', torch.Size([512]))
# ('layers.fc4.1.weight', ':', torch.Size([512, 4608]))
# ('layers.fc4.1.bias', ':', torch.Size([512]))
# ('layers.fc5.1.weight', ':', torch.Size([512, 512]))
# ('layers.fc5.1.bias', ':', torch.Size([512]))
# ('seblocks.conv3_se.1.weight', ':', torch.Size([32, 512]))
# ('seblocks.conv3_se.1.bias', ':', torch.Size([32]))
# ('seblocks.conv3_se.3.weight', ':', torch.Size([512, 32]))
# ('seblocks.conv3_se.3.bias', ':', torch.Size([512]))
# ('attmask.conv1_theta.0.weight', ':', torch.Size([48, 96, 1, 1]))
# ('attmask.conv1_theta.0.bias', ':', torch.Size([48]))
# ('attmask.conv1_phi.0.weight', ':', torch.Size([48, 96, 1, 1]))
# ...
