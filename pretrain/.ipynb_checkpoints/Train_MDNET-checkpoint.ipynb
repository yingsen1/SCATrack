# %%
from train_mdnet_tensorboard_try import *

# %%
print(opts['model_path'])
opts['model_path'] = '../models/pymdnet-vot-attmask2-conv1&se3-try-1010.pth'
print(opts['model_path'])
# Out:
# ../models/pymdnet-vot-seblock-r16-0921.pth
# ../models/pymdnet-vot-attmask2-conv1&se3-1010.pth

# %%
train_mdnet()
# Out:
# ../models/imagenet-vgg-m.mat
# ../models/imagenet-vgg-m.mat
# conv3_se_weight have already in param, so plus _2
# conv3_se_bias have already in param, so plus _2
# ==== Start Cycle 0 ====
# Cycle  0, K  0 (32), Loss 228.257, Prec 0.156, Time 5.861
# Cycle  0, K  1 (43), Loss 117.395, Prec 0.156, Time 0.447
# Cycle  0, K  2 (49), Loss 174.294, Prec 0.500, Time 0.314
# Cycle  0, K  3 (48), Loss 159.258, Prec 0.219, Time 0.698
# Cycle  0, K  4 (29), Loss 146.916, Prec 0.344, Time 0.538
# Cycle  0, K  5 (19), Loss 159.768, Prec 0.219, Time 0.397
# Cycle  0, K  6 (10), Loss 116.797, Prec 0.281, Time 0.352
# Cycle  0, K  7 (46), Loss 129.004, Prec 0.281, Time 0.335
# Cycle  0, K  8 (51), Loss 115.101, Prec 0.312, Time 0.326
# Cycle  0, K  9 (11), Loss 156.954, Prec 0.344, Time 0.397
# Cycle  0, K 10 (14), Loss 275.167, Prec 0.406, Time 0.415
# Cycle  0, K 11 (35), Loss 120.543, Prec 0.344, Time 0.499
# Cycle  0, K 12 (47), Loss 126.260, Prec 0.344, Time 0.386
# ...

# %%
# conv2重新做
